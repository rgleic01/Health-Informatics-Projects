# %% [markdown]
# # Import data and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cities = pd.read_csv("CHDB_data_city_all v7_1.csv")
print("Dataset dimensions: " + str(cities.shape))
# Take a look at the number of unique values for each column
for col_name in cities.columns:
    column = cities[col_name]
    print(col_name + ": "  + str(column.nunique()))
# Out:
# Dataset dimensions: (60500, 22)
# state_abbr: 51
# state_fips: 51
# place_fips: 397
# stpl_fips: 500
# city_name: 474
# metric_name: 36
# group_name: 14
# metric_number: 36
# group_number: 14
# num: 9469
# denom: 13957
# est: 3217
# lci: 2839
# uci: 3133
# county_indicator: 4
# educ_indicator: 3
# multiplier_indicator: 2
# data_yr_type: 12
# geo_level: 1
# date_export: 1
# version: 1
# NOTE - NCHS Disclaimer: 1

# %% [markdown]
# # 1. Generate rankings for 500 cities, print where Flint is in bottom 3%

# %%
# eliminate all extraneous columns (year of collection, state code, etc.)
metrics = cities[['metric_name', 'num', 'denom', 'est']]

# create descrtive statistics for all cities
overall_avg = metrics.groupby(['metric_name']).mean()

total_pop = cities[cities['group_name'] == 'total population']
overall_metrics = total_pop[['city_name', 'metric_name', 'est']]

print("Categories where Flint is in the bottom 3%: \n")
print("Out of 500 cities, Flint is ranked...")
for metric in overall_metrics.metric_name.unique():
    metric_df = overall_metrics[overall_metrics['metric_name'] == metric]
    sorted_df = metric_df.sort_values(['est'])
    sorted_df = sorted_df.reset_index(drop=True)
    flint_rank = np.where(sorted_df['city_name'] == 'Flint')[0]
    flint_rank += 1
    if flint_rank < 30:
        flint_rank = abs(flint_rank - 500)
    if int(str(flint_rank)[1:-1]) < 30 or int(str(flint_rank)[1:-1]) > 470:
        print(str(flint_rank)[1:-1] + ' in ' + metric)
# Out:
# Categories where Flint is in the bottom 3%:
#
# Out of 500 cities, Flint is ranked...
# 500 in Children in Poverty
# 480 in Dental care
# 495 in Diabetes
# 500 in Frequent mental distress
# 500 in Frequent physical distress
# 488 in High blood pressure
# 499 in Income Inequality
# 482 in Lead exposure risk index
# 477 in Neighborhood racial/ethnic segregation
# 498 in Obesity
# 476 in Physical inactivity
# 488 in Preventive services
# 500 in Smoking
# 481 in Third-grade reading proficiency
# 500 in Unemployment
# 476 in Cardiovascular disease deaths
# 477 in Colorectal cancer deaths
# 487 in Premature deaths (all causes)
# 496 in Life expectancy

# %%
# create dataset specificalle for flint
flint_total = cities[(cities['city_name'] == 'Flint') & (cities['group_name'] == 'total population')]
flint_vals = flint_total[['metric_name', 'est']]
flint_vals.set_index('metric_name', inplace=True)
#drop gender/ethnic subcategories, keep total population
metrics_totalpop = cities[cities['group_name'] == 'total population']
overall_stats = metrics_totalpop[['metric_name', 'est']].groupby(['metric_name']).describe()

# in what categories is Flint an outlier?
# calculate dc's z-score for each metrics
overall_stats.columns = overall_stats.columns.get_level_values(1)
overall_stats['flint_avg'] = flint_vals['est']
overall_stats['flint_z-score'] = (overall_stats['flint_avg'] - overall_stats['mean']) / overall_stats['std']
print("Stats for all 500 cities:")
overall_stats
# Out:
# Stats for all 500 cities:
#                                         count         mean          std  \
# metric_name
# Absenteeism                             500.0    18.073200     9.341169
# Air pollution - particulate matter      498.0     9.191165     1.692985
# Binge drinking                          500.0    17.656200     2.684346
# Breast cancer deaths                    492.0    24.428049     6.056955
# Cardiovascular disease deaths           494.0   210.440486    58.725131
# Children in Poverty                     500.0    22.625400    10.899536
# Colorectal cancer deaths                492.0    16.099187     4.207326
# Dental care                             500.0    63.196000     7.546653
# Diabetes                                500.0     9.997800     2.397196
# Frequent mental distress                500.0    12.833200     2.061543
# Frequent physical distress              500.0    12.269600     2.453576
# High blood pressure                     500.0    29.396400     5.016536
# High school graduation                  478.0    83.371757     9.799965
# Housing cost, excessive                 500.0    37.004600     7.230979
# Housing with potential lead risk        500.0    18.507400    12.450491
# Income Inequality                       500.0    -5.481600    17.893668
# Lead exposure risk index                500.0     5.500000     2.875158
# Life expectancy                         492.0    78.826829     2.314017
# Limited access to healthy foods         500.0    61.910600    17.949108
# Low birthweight                         273.0     8.518681     1.864623
# Neighborhood racial/ethnic segregation  500.0    12.359000     7.088658
# Obesity                                 500.0    29.247600     5.753198
# Opioid overdose deaths                  428.0    14.978505    13.321137
# Park access                             500.0    60.596400    22.604089
# Physical inactivity                     500.0    23.992000     6.468535
# Premature deaths (all causes)           495.0  7510.505051  2856.353588
# Prenatal care                           246.0    77.635366     8.518360
# Preventive services                     500.0    32.585800     4.954973
# Racial/ethnic diversity                 500.0    64.086800    14.622094
# Smoking                                 500.0    17.394000     4.098042
# Teen births                             273.0    24.361172    13.346916
# Third-grade reading proficiency         499.0    46.192585    17.990903
# Unemployment                            500.0     7.169400     2.694908
# Uninsured                               500.0    12.860000     5.690980
# Violent crime                           468.0   513.545940   366.814577
# Walkability                             500.0    44.509000    15.788077
#
#                                           min       25%      50%       75%  \
# metric_name
# Absenteeism                               0.0    11.800    16.25    22.500
# Air pollution - particulate matter        4.9     7.900     9.15    10.300
# Binge drinking                            9.1    16.000    17.55    19.200
# Breast cancer deaths                     11.3    20.300    23.70    27.900
# Cardiovascular disease deaths            46.7   171.350   202.75   236.825
# Children in Poverty                       2.4    14.375    22.15    29.725
# Colorectal cancer deaths                  4.1    13.500    15.70    18.325
# Dental care                              42.3    57.600    63.30    68.700
# Diabetes                                  4.2     8.275     9.80    11.500
# Frequent mental distress                  7.9    11.400    12.90    14.300
# Frequent physical distress                7.1    10.500    12.30    13.925
# High blood pressure                      15.6    26.100    28.80    32.500
# High school graduation                   27.3    78.500    85.20    90.400
# Housing cost, excessive                  18.8    31.900    36.50    42.200
# Housing with potential lead risk          1.4     8.300    15.20    26.500
# Income Inequality                       -45.9   -18.200    -8.70     5.500
# Lead exposure risk index                  1.0     3.000     5.50     8.000
# Life expectancy                          72.0    77.375    78.80    80.500
# Limited access to healthy foods           0.0    52.250    65.40    75.325
# Low birthweight                           5.0     7.200     8.30     9.600
# Neighborhood racial/ethnic segregation    2.0     7.200    10.70    15.525
# Obesity                                  14.9    25.100    29.20    33.200
# Opioid overdose deaths                    2.0     6.575    10.35    17.400
# Park access                               7.2    44.375    62.70    77.500
# Physical inactivity                      10.1    18.800    23.85    28.200
# Premature deaths (all causes)           100.0  5400.000  7000.00  9300.000
# Prenatal care                            52.0    71.900    77.60    85.250
# Preventive services                      18.4    29.500    32.45    35.925
# Racial/ethnic diversity                  13.7    55.600    66.00    74.925
# Smoking                                   8.6    14.300    17.10    20.100
# Teen births                               0.8    14.300    24.60    33.600
# Third-grade reading proficiency          11.2    31.600    44.20    58.650
# Unemployment                              3.0     5.300     6.65     8.425
# Uninsured                                 2.0     9.000    11.95    15.900
# Violent crime                            19.6   242.875   416.90   697.650
# Walkability                               6.5    33.700    41.50    54.350
#
#                                             max  flint_avg  flint_z-score
# metric_name
# Absenteeism                                65.8       28.2       1.084104
# Air pollution - particulate matter         15.7        9.5       0.182421
# Binge drinking                             27.4       15.2      -0.915009
# Breast cancer deaths                       50.6       28.2       0.622747
# Cardiovascular disease deaths             515.2      338.4       2.178957
# Children in Poverty                        60.0       60.0       3.429008
# Colorectal cancer deaths                   34.3       24.6       2.020479
# Dental care                                81.8       50.8      -1.642583
# Diabetes                                   21.6       16.6       2.754135
# Frequent mental distress                   18.4       18.4       2.700308
# Frequent physical distress                 19.9       19.9       3.109910
# High blood pressure                        49.2       41.0       2.313070
# High school graduation                     98.6       70.2      -1.344062
# Housing cost, excessive                    59.6       42.7       0.787639
# Housing with potential lead risk           53.2       36.6       1.453164
# Income Inequality                          51.2      -45.9      -2.258810
# Lead exposure risk index                   10.0       10.0       1.565131
# Life expectancy                            85.1       72.7      -2.647702
# Limited access to healthy foods            93.6       72.4       0.584397
# Low birthweight                            15.6       14.4       3.154160
# Neighborhood racial/ethnic segregation     44.6       27.6       2.150054
# Obesity                                    49.1       45.0       2.738025
# Opioid overdose deaths                    116.2       28.7       1.030054
# Park access                                99.9       82.6       0.973434
# Physical inactivity                        46.8       35.3       1.748155
# Premature deaths (all causes)           18100.0    14900.0       2.587038
# Prenatal care                              94.3       76.4      -0.145024
# Preventive services                        47.7       21.5      -2.237308
# Racial/ethnic diversity                    94.3       61.9      -0.149555
# Smoking                                    29.7       29.7       3.002897
# Teen births                                84.8       52.1       2.078295
# Third-grade reading proficiency            91.1       18.2      -1.555930
# Unemployment                               22.2       22.2       5.577408
# Uninsured                                  35.2       10.2      -0.467406
# Violent crime                            2044.4     1899.6       3.778623
# Walkability                                94.2       43.1      -0.089245

# %% [markdown]
# # 2. Find outcomes correlated with absenteeism, binge drinking, and segregation

# %%
# transform to pivot table for correlation analysis
df = metrics_totalpop[['city_name', 'metric_name', 'est']]
pivot = pd.pivot_table(df, index='city_name', columns='metric_name', values='est')
pivot.shape
# Out:
# (474, 36)

# %%
# Drop all determinants except Absenteeism, Binge Drinking, and Segregation
# include the eleven health outcomes
pivot = pivot[['Absenteeism', 'Breast cancer deaths', 'Cardiovascular disease deaths', 
               'Colorectal cancer deaths', 'Diabetes', 'Frequent mental distress', 
               'High blood pressure', 'Life expectancy', 'Low birthweight', 
               'Obesity', 'Opioid overdose deaths', 'Premature deaths (all causes)', 
               'Binge drinking', 'Neighborhood racial/ethnic segregation']]

# print correlation coefficient matrix
corr = pivot.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col4 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col5 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col6 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col7 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col8 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col9 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col10 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col11 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col12 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row0_col13 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col2 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col3 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col4 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col5 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col6 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col8 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col9 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col10 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col11 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col12 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row1_col13 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col0 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col1 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col3 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col4 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col5 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col6 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col7 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col8 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col9 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col10 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col11 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col12 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row2_col13 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col0 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col1 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col2 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col4 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col5 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col6 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col7 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col8 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col9 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col10 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col11 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col12 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row3_col13 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row4_col0 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row4_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row4_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_8f497f94_f749_11e9_a6cc_80e6500631c8row4_col3 {
#             background-color:  #f4c5ad;
#             colo

# %% [markdown]
# # 3. Analysis within Flint @ level of census tracts

# %%
# read in csv file
tracts = pd.read_csv('CHDB_data_tract_MI v7_1.csv')

# eliminate extraneous columns, keep only tract, metric name, and metric value
tracts = tracts[['tract_code', 'metric_name', 'est']]

#create pivot table
tracts_pivot = pd.pivot_table(tracts, index='tract_code', columns='metric_name', values='est')
tracts_pivot.columns
# Out:
# Index(['Air pollution - particulate matter', 'Binge drinking',
#        'Children in Poverty', 'Dental care', 'Diabetes',
#        'Frequent mental distress', 'Frequent physical distress',
#        'High blood pressure', 'Housing cost, excessive',
#        'Housing with potential lead risk', 'Income Inequality',
#        'Lead exposure risk index', 'Life expectancy',
#        'Limited access to healthy foods', 'Obesity', 'Physical inactivity',
#        'Preventive services', 'Racial/ethnic diversity', 'Smoking',
#        'Unemployment', 'Uninsured'],
#       dtype='object', name='metric_name')

# %%
# print correlation coefficient matrix
tracts_corr = tracts_pivot.corr()
tracts_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col1 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col2 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col4 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col5 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col6 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col7 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col8 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col9 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col11 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col12 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col13 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col14 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col15 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col16 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col17 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col18 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col19 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row0_col20 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col2 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col3 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col5 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col6 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col8 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col9 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col10 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col11 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col12 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col13 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col14 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col15 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col16 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col17 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col18 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col19 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row1_col20 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col0 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col4 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col5 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col6 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col7 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col8 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col9 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col10 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col11 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col12 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col13 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col14 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col15 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col16 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_26c9a93a_f749_11e9_a6cc_80e6500631c8row2_col17 {
#             background-color:  #7295f4;
